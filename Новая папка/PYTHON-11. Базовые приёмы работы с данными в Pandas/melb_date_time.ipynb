# %%
import pandas as pd

melb_data = pd.read_csv('C:\VS Code\melb_data.csv', sep=',')
melb_df = melb_data.copy()
melb_df.head()
display(melb_df['Date'])
melb_df['Date'] = pd.to_datetime(melb_df['Date'], dayfirst=True)
display(melb_df['Date'])
# Out:
# 0         3/12/2016
# 1         4/02/2016
# 2         4/03/2017
# 3         4/03/2017
# 4         4/06/2016
#             ...
# 13575    26/08/2017
# 13576    26/08/2017
# 13577    26/08/2017
# 13578    26/08/2017
# 13579    26/08/2017
# Name: Date, Length: 13580, dtype: object
# 0       2016-12-03
# 1       2016-02-04
# 2       2017-03-04
# 3       2017-03-04
# 4       2016-06-04
#            ...
# 13575   2017-08-26
# 13576   2017-08-26
# 13577   2017-08-26
# 13578   2017-08-26
# 13579   2017-08-26
# Name: Date, Length: 13580, dtype: datetime64[ns]

# %%
years_sold = melb_df['Date'].dt.year
print(years_sold)
print('Min year sold:', years_sold.min())
print('Max year sold:', years_sold.max())
print('Mode year sold:', years_sold.mode()[0])
# Out:
# 0        2016
# 1        2016
# 2        2017
# 3        2017
# 4        2016
#          ...
# 13575    2017
# 13576    2017
# 13577    2017
# 13578    2017
# 13579    2017
# Name: Date, Length: 13580, dtype: int32
# Min year sold: 2016
# Max year sold: 2017
# Mode year sold: 2017

# %%
melb_df['MonthSale'] = melb_df['Date'].dt.month
melb_df['MonthSale'].value_counts(normalize=True)
# Out:
# MonthSale
# 5     0.149411
# 7     0.145950
# 9     0.135862
# 6     0.134757
# 8     0.114138
# 11    0.082032
# 4     0.069882
# 3     0.049926
# 12    0.044698
# 10    0.040574
# 2     0.032622
# 1     0.000147
# Name: proportion, dtype: float64

# %%
melb_df['AgeBuilding'] = melb_df['Date'].dt.year - melb_df['YearBuilt']
display(melb_df['AgeBuilding'])
# Out:
# 0         46.0
# 1        116.0
# 2        117.0
# 3         47.0
# 4          2.0
#          ...
# 13575     36.0
# 13576     22.0
# 13577     20.0
# 13578     97.0
# 13579     97.0
# Name: AgeBuilding, Length: 13580, dtype: float64

# %%
melb_df = melb_df.drop('YearBuilt', axis=1)
melb_df.head()
# Out:
#    index      Suburb           Address  Rooms Type      Price Method SellerG
# 0      0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin  \
# 1      1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2      2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3      3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4      4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  ...  Landsize  BuildingArea  CouncilArea  Lattitude
# 0 2016-12-03       2.5  ...     202.0         126.0        Yarra   -37.7996  \
# 1 2016-02-04       2.5  ...     156.0          79.0        Yarra   -37.8079
# 2 2017-03-04       2.5  ...     134.0         150.0        Yarra   -37.8093
# 3 2017-03-04       2.5  ...      94.0         126.0        Yarra   -37.7969
# 4 2016-06-04       2.5  ...     120.0         142.0        Yarra   -37.8072
#
#    Longtitude             Regionname Propertycount         Coordinates
# 0    144.9984  Northern Metropolitan        4019.0  -37.7996, 144.9984  \
# 1    144.9934  Northern Metropolitan        4019.0  -37.8079, 144.9934
# 2    144.9944  Northern Metropolitan        4019.0  -37.8093, 144.9944
# 3    144.9969  Northern Metropolitan        4019.0  -37.7969, 144.9969
# 4    144.9941  Northern Metropolitan        4019.0  -37.8072, 144.9941
#
#    MonthSale AgeBuilding
# 0         12        46.0
# 1          2       116.0
# 2          3       117.0
# 3          3        47.0
# 4          6         2.0
#
# [5 rows x 24 columns]

# %%
melb_df['WeekdaySale'] = melb_df['Date'].dt.dayofweek
melb_df['WeekdaySale'].value_counts()[6] + melb_df['WeekdaySale'].value_counts()[5]
display(melb_df['WeekdaySale'])
display(melb_df)
# Out:
# 0        5
# 1        3
# 2        5
# 3        5
# 4        5
#         ..
# 13575    5
# 13576    5
# 13577    5
# 13578    5
# 13579    5
# Name: WeekdaySale, Length: 13580, dtype: int32
#        index         Suburb           Address  Rooms Type      Price Method
# 0          0     Abbotsford      85 Turner St      2    h  1480000.0      S  \
# 1          1     Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2          2     Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3          3     Abbotsford  40 Federation La      3    h   850000.0     PI
# 4          4     Abbotsford       55a Park St      4    h  1600000.0     VB
# ...      ...            ...               ...    ...  ...        ...    ...
# 13575  13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576  13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577  13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578  13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579  13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#         SellerG       Date  Distance  ...  BuildingArea  CouncilArea
# 0        Biggin 2016-12-03       2.5  ...         126.0        Yarra  \
# 1        Biggin 2016-02-04       2.5  ...          79.0        Yarra
# 2        Biggin 2017-03-04       2.5  ...         150.0        Yarra
# 3        Biggin 2017-03-04       2.5  ...         126.0        Yarra
# 4        Nelson 2016-06-04       2.5  ...         142.0        Yarra
# ...         ...        ...       ...  ...           ...          ...
# 13575     Barry 2017-08-26      16.7  ...         126.0          NaN
# 13576  Williams 2017-08-26       6.8  ...         133.0          NaN
# 13577     Raine 2017-08-26       6.8  ...         126.0          NaN
# 13578   Sweeney 2017-08-26       6.8  ...         157.0          NaN
# 13579   Village 2017-08-26       6.3  ...         112.0          NaN
#
#        Lattitude  Longtitude                  Regionname  Propertycount
# 0      -37.79960   144.99840       Northern Metropolitan         4019.0  \
# 1      -37.80790   144.99340       Northern Metropolitan         4019.0
# 2      -37.80930   144.99440       Northern Metropolitan         4019.0
# 3      -37.79690   144.99690       Northern Metropolitan         4019.0
# 4      -37.80720   144.99410       Northern Metropolitan         4019.0
# ...          ...         ...                         ...            ...
# 13575  -37.90562   145.16761  South-Eastern Metropolitan         7392.0
# 13576  -37.85927   144.87904        Western Metropolitan         6380.0
# 13577  -37.85274   144.88738        Western Metropolitan         6380.0
# 13578  -37.85908   144.89299        Western Metropolitan         6380.0
# 13579  -37.81188   144.88449        Western Metropolitan         6543.0
#
#                 Coordinates  MonthSale  AgeBuilding WeekdaySale
# 0        -37.7996, 144.9984         12         46.0           5
# 1        -37.8079, 144.9934          2        116.0           3
# 2        -37.8093, 144.9944          3        117.0           5
# 3        -37.7969, 144.9969          3         47.0           5
# 4        -37.8072, 144.9941          6          2.0           5
# ...                     ...        ...          ...         ...
# 13575  -37.90562, 145.16761          8         36.0           5
# 13576  -37.85927, 144.87904          8         22.0           5
# 13577  -37.85274, 144.88738          8         20.0           5
# 13578  -37.85908, 144.89299          8         97.0           5
# 13579  -37.81188, 144.88449          8         97.0           5
#
# [13580 rows x 25 columns]
