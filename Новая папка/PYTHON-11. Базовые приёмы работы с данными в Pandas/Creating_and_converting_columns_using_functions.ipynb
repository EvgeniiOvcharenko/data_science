# %%
import pandas as pd
melb_data = pd.read_csv('C:\VS Code\melb_data.csv', sep=',')
melb_df = melb_data.copy()
display(melb_df)
# Out:
#        index         Suburb           Address  Rooms Type      Price Method
# 0          0     Abbotsford      85 Turner St      2    h  1480000.0      S  \
# 1          1     Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2          2     Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3          3     Abbotsford  40 Federation La      3    h   850000.0     PI
# 4          4     Abbotsford       55a Park St      4    h  1600000.0     VB
# ...      ...            ...               ...    ...  ...        ...    ...
# 13575  13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576  13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577  13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578  13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579  13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#         SellerG        Date  Distance  ...  Car  Landsize  BuildingArea
# 0        Biggin   3/12/2016       2.5  ...  1.0     202.0         126.0  \
# 1        Biggin   4/02/2016       2.5  ...  0.0     156.0          79.0
# 2        Biggin   4/03/2017       2.5  ...  0.0     134.0         150.0
# 3        Biggin   4/03/2017       2.5  ...  1.0      94.0         126.0
# 4        Nelson   4/06/2016       2.5  ...  2.0     120.0         142.0
# ...         ...         ...       ...  ...  ...       ...           ...
# 13575     Barry  26/08/2017      16.7  ...  2.0     652.0         126.0
# 13576  Williams  26/08/2017       6.8  ...  2.0     333.0         133.0
# 13577     Raine  26/08/2017       6.8  ...  4.0     436.0         126.0
# 13578   Sweeney  26/08/2017       6.8  ...  5.0     866.0         157.0
# 13579   Village  26/08/2017       6.3  ...  1.0     362.0         112.0
#
#        YearBuilt  CouncilArea  Lattitude  Longtitude
# 0         1970.0        Yarra  -37.79960   144.99840  \
# 1         1900.0        Yarra  -37.80790   144.99340
# 2         1900.0        Yarra  -37.80930   144.99440
# 3         1970.0        Yarra  -37.79690   144.99690
# 4         2014.0        Yarra  -37.80720   144.99410
# ...          ...          ...        ...         ...
# 13575     1981.0          NaN  -37.90562   145.16761
# 13576     1995.0          NaN  -37.85927   144.87904
# 13577     1997.0          NaN  -37.85274   144.88738
# 13578     1920.0          NaN  -37.85908   144.89299
# 13579     1920.0          NaN  -37.81188   144.88449
#
#                        Regionname  Propertycount           Coordinates
# 0           Northern Metropolitan         4019.0    -37.7996, 144.9984
# 1           Northern Metropolitan         4019.0    -37.8079, 144.9934
# 2           Northern Metropolitan         4019.0    -37.8093, 144.9944
# 3           Northern Metropolitan         4019.0    -37.7969, 144.9969
# 4           Northern Metropolitan         4019.0    -37.8072, 144.9941
# ...                           ...            ...                   ...
# 13575  South-Eastern Metropolitan         7392.0  -37.90562, 145.16761
# 13576        Western Metropolitan         6380.0  -37.85927, 144.87904
# 13577        Western Metropolitan         6380.0  -37.85274, 144.88738
# 13578        Western Metropolitan         6380.0  -37.85908, 144.89299
# 13579        Western Metropolitan         6543.0  -37.81188, 144.88449
#
# [13580 rows x 23 columns]

# %%
print(melb_df['Address'].nunique())
# Out:
# 13378

# %%
def get_street_type(address):
# Создаём список географических пометок exclude_list.
    exclude_list = ['N', 'S', 'W', 'E']
# Метод split() разбивает строку на слова по пробелу.
# В результате получаем список слов в строке и заносим его в переменную address_list.
    address_list = address.split(' ')
# Обрезаем список, оставляя в нём только последний элемент,
# потенциальный подтип улицы, и заносим в переменную street_type.
    street_type = address_list[-1]
# Делаем проверку на то, что полученный подтип является географической пометкой.
# Для этого проверяем его на наличие в списке exclude_list.
    if street_type in exclude_list:
# Если переменная street_type является географической пометкой,
# переопределяем её на второй элемент с конца списка address_list.
        street_type = address_list[-2]
# Возвращаем переменную street_type, в которой хранится подтип улицы.
    if street_type == 'Avenue':
        street_type = 'Av'
    
    if street_type == 'Boulevard':
        street_type = 'Bvd'
    
    if street_type == 'Parade':
        street_type = 'Pde'
    return street_type

street_types = melb_df['Address'].apply(get_street_type)
display(street_types)
# Out:
# 0        St
# 1        St
# 2        St
# 3        La
# 4        St
#          ..
# 13575    Cr
# 13576    Dr
# 13577    St
# 13578    St
# 13579    St
# Name: Address, Length: 13580, dtype: object

# %%
print(street_types.nunique())
display(street_types.value_counts())
# Out:
# 53
# Address
# St           8012
# Rd           2825
# Ct            612
# Dr            447
# Av            361
# Gr            311
# Pde           226
# Pl            169
# Cr            152
# Cl            100
# La             67
# Bvd            66
# Tce            47
# Wy             40
# Cct            25
# Hwy            24
# Sq             11
# Crescent        9
# Cir             7
# Strand          7
# Esplanade       6
# Grove           5
# Mews            4
# Grn             4
# Fairway         4
# Gdns            4
# Righi           3
# Crossway        3
# Esp             2
# Victoria        2
# Ridge           2
# Crofts          2
# Grand           1
# Summit          1
# Hts             1
# Athol           1
# Highway         1
# Outlook         1
# Woodland        1
# Ave             1
# Gra             1
# Terrace         1
# Eyrie           1
# Dell            1
# East            1
# Loop            1
# Nook            1
# Glade           1
# Qy              1
# Cove            1
# Res             1
# Grange          1
# Corso           1
# Name: count, dtype: int64

# %%
popular_stypes =street_types.value_counts().nlargest(10).index
melb_df['StreetType'] = street_types.apply(lambda x: x if x in popular_stypes else 'other')
print(melb_df['StreetType'].nunique())
melb_df = melb_df.drop('Address', axis=1)
display(melb_df)
# Out:
# 11
#        index         Suburb  Rooms Type      Price Method   SellerG
# 0          0     Abbotsford      2    h  1480000.0      S    Biggin  \
# 1          1     Abbotsford      2    h  1035000.0      S    Biggin
# 2          2     Abbotsford      3    h  1465000.0     SP    Biggin
# 3          3     Abbotsford      3    h   850000.0     PI    Biggin
# 4          4     Abbotsford      4    h  1600000.0     VB    Nelson
# ...      ...            ...    ...  ...        ...    ...       ...
# 13575  13575  Wheelers Hill      4    h  1245000.0      S     Barry
# 13576  13576   Williamstown      3    h  1031000.0     SP  Williams
# 13577  13577   Williamstown      3    h  1170000.0      S     Raine
# 13578  13578   Williamstown      4    h  2500000.0     PI   Sweeney
# 13579  13579     Yarraville      4    h  1285000.0     SP   Village
#
#              Date  Distance  Postcode  ...  Landsize  BuildingArea  YearBuilt
# 0       3/12/2016       2.5      3067  ...     202.0         126.0     1970.0  \
# 1       4/02/2016       2.5      3067  ...     156.0          79.0     1900.0
# 2       4/03/2017       2.5      3067  ...     134.0         150.0     1900.0
# 3       4/03/2017       2.5      3067  ...      94.0         126.0     1970.0
# 4       4/06/2016       2.5      3067  ...     120.0         142.0     2014.0
# ...           ...       ...       ...  ...       ...           ...        ...
# 13575  26/08/2017      16.7      3150  ...     652.0         126.0     1981.0
# 13576  26/08/2017       6.8      3016  ...     333.0         133.0     1995.0
# 13577  26/08/2017       6.8      3016  ...     436.0         126.0     1997.0
# 13578  26/08/2017       6.8      3016  ...     866.0         157.0     1920.0
# 13579  26/08/2017       6.3      3013  ...     362.0         112.0     1920.0
#
#        CouncilArea  Lattitude  Longtitude                  Regionname
# 0            Yarra  -37.79960   144.99840       Northern Metropolitan  \
# 1            Yarra  -37.80790   144.99340       Northern Metropolitan
# 2            Yarra  -37.80930   144.99440       Northern Metropolitan
# 3            Yarra  -37.79690   144.99690       Northern Metropolitan
# 4            Yarra  -37.80720   144.99410       Northern Metropolitan
# ...            ...        ...         ...                         ...
# 13575          NaN  -37.90562   145.16761  South-Eastern Metropolitan
# 13576          NaN  -37.85927   144.87904        Western Metropolitan
# 13577          NaN  -37.85274   144.88738        Western Metropolitan
# 13578          NaN  -37.85908   144.89299        Western Metropolitan
# 13579          NaN  -37.81188   144.88449        Western Metropolitan
#
#        Propertycount           Coordinates StreetType
# 0             4019.0    -37.7996, 144.9984         St
# 1             4019.0    -37.8079, 144.9934         St
# 2             4019.0    -37.8093, 144.9944         St
# 3             4019.0    -37.7969, 144.9969      other
# 4             4019.0    -37.8072, 144.9941         St
# ...              ...                   ...        ...
# 13575         7392.0  -37.90562, 145.16761         Cr
# 13576         6380.0  -37.85927, 144.87904         Dr
# 13577         6380.0  -37.85274, 144.88738         St
# 13578         6380.0  -37.85908, 144.89299         St
# 13579         6543.0  -37.81188, 144.88449         St
#
# [13580 rows x 23 columns]

# %% [markdown]
# Напишите функцию get_weekend(weekday), которая принимает на вход элемент столбца WeekdaySale и возвращает 1, если день является выходным, и 0 — в противном случае, и создайте столбец Weekend в таблице melb_df с помощью неё.

# %%
melb_df['Date'] = pd.to_datetime(melb_df['Date'], dayfirst=True)
melb_df['WeekdaySale'] = melb_df['Date'].dt.dayofweek

display(melb_df['WeekdaySale'])
display(melb_df)
# Out:
# 0        5
# 1        3
# 2        5
# 3        5
# 4        5
#         ..
# 13575    5
# 13576    5
# 13577    5
# 13578    5
# 13579    5
# Name: WeekdaySale, Length: 13580, dtype: int32
#        index         Suburb  Rooms Type      Price Method   SellerG
# 0          0     Abbotsford      2    h  1480000.0      S    Biggin  \
# 1          1     Abbotsford      2    h  1035000.0      S    Biggin
# 2          2     Abbotsford      3    h  1465000.0     SP    Biggin
# 3          3     Abbotsford      3    h   850000.0     PI    Biggin
# 4          4     Abbotsford      4    h  1600000.0     VB    Nelson
# ...      ...            ...    ...  ...        ...    ...       ...
# 13575  13575  Wheelers Hill      4    h  1245000.0      S     Barry
# 13576  13576   Williamstown      3    h  1031000.0     SP  Williams
# 13577  13577   Williamstown      3    h  1170000.0      S     Raine
# 13578  13578   Williamstown      4    h  2500000.0     PI   Sweeney
# 13579  13579     Yarraville      4    h  1285000.0     SP   Village
#
#             Date  Distance  Postcode  ...  BuildingArea  YearBuilt
# 0     2016-12-03       2.5      3067  ...         126.0     1970.0  \
# 1     2016-02-04       2.5      3067  ...          79.0     1900.0
# 2     2017-03-04       2.5      3067  ...         150.0     1900.0
# 3     2017-03-04       2.5      3067  ...         126.0     1970.0
# 4     2016-06-04       2.5      3067  ...         142.0     2014.0
# ...          ...       ...       ...  ...           ...        ...
# 13575 2017-08-26      16.7      3150  ...         126.0     1981.0
# 13576 2017-08-26       6.8      3016  ...         133.0     1995.0
# 13577 2017-08-26       6.8      3016  ...         126.0     1997.0
# 13578 2017-08-26       6.8      3016  ...         157.0     1920.0
# 13579 2017-08-26       6.3      3013  ...         112.0     1920.0
#
#        CouncilArea  Lattitude  Longtitude                  Regionname
# 0            Yarra  -37.79960   144.99840       Northern Metropolitan  \
# 1            Yarra  -37.80790   144.99340       Northern Metropolitan
# 2            Yarra  -37.80930   144.99440       Northern Metropolitan
# 3            Yarra  -37.79690   144.99690       Northern Metropolitan
# 4            Yarra  -37.80720   144.99410       Northern Metropolitan
# ...            ...        ...         ...                         ...
# 13575          NaN  -37.90562   145.16761  South-Eastern Metropolitan
# 13576          NaN  -37.85927   144.87904        Western Metropolitan
# 13577          NaN  -37.85274   144.88738        Western Metropolitan
# 13578          NaN  -37.85908   144.89299        Western Metropolitan
# 13579          NaN  -37.81188   144.88449        Western Metropolitan
#
#       Propertycount           Coordinates  StreetType WeekdaySale
# 0            4019.0    -37.7996, 144.9984          St           5
# 1            4019.0    -37.8079, 144.9934          St           3
# 2            4019.0    -37.8093, 144.9944          St           5
# 3            4019.0    -37.7969, 144.9969       other           5
# 4            4019.0    -37.8072, 144.9941          St           5
# ...             ...                   ...         ...         ...
# 13575        7392.0  -37.90562, 145.16761          Cr           5
# 13576        6380.0  -37.85927, 144.87904          Dr           5
# 13577        6380.0  -37.85274, 144.88738          St           5
# 13578        6380.0  -37.85908, 144.89299          St           5
# 13579        6543.0  -37.81188, 144.88449          St           5
#
# [13580 rows x 24 columns]

# %%
def get_weekend(weekday):
    if weekday == 6 or weekday == 5:
        return 1
    return 0
melb_df['Weekend'] = melb_df['WeekdaySale'].apply(get_weekend)
display(melb_df[melb_df['Weekend'] == 1]['Price'].mean())
# Out:
# 1081198.6406956792

# %% [markdown]
# Преобразуйте столбец SellerG с наименованиями риелторских компаний в таблице melb_df следующим образом: оставьте в столбце только 49 самых популярных компаний, а остальные обозначьте как 'other'.
# Найдите, во сколько раз минимальная цена объектов недвижимости, проданных компанией 'Nelson', больше минимальной цены объектов, проданных компаниями, обозначенными как 'other'

# %%
print(melb_df['SellerG'].nunique())
popular_seller = melb_df['SellerG'].value_counts().nlargest(49).index
melb_df['SellerG'] = melb_df['SellerG'].apply(lambda x: x if x in popular_seller else 'other')
print(melb_df['SellerG'])
print(melb_df['SellerG'].nunique())
# Out:
# 268
# 0          Biggin
# 1          Biggin
# 2          Biggin
# 3          Biggin
# 4          Nelson
#            ...
# 13575       Barry
# 13576    Williams
# 13577       Raine
# 13578     Sweeney
# 13579     Village
# Name: SellerG, Length: 13580, dtype: object
# 50

# %%
melb_df[melb_df['SellerG'] == 'Nelson']['Price'].min()
melb_df[melb_df['SellerG'] == 'other']['Price'].min()
melb_df[melb_df['SellerG'] == 'Nelson']['Price'].min() / melb_df[melb_df['SellerG'] == 'other']['Price'].min()
# Out:
# 1.297709923664122

# %% [markdown]
# Представьте, что вы занимаетесь подготовкой данных о вакансиях с платформы hh.ru. В вашем распоряжении имеется таблица, в которой с помощью парсинга собраны резюме кандидатов. В этой таблице есть текстовый столбец «Опыт работы». Пример такого столбца представлен ниже в виде объекта Series. Структура текста в столбце фиксирована и не может измениться.
#
# Напишите функцию get_experience(arg), аргументом которой является строка столбца с опытом работы. Функция должна возвращать опыт работы в месяцах. Не забудьте привести результат к целому числу.

# %%
def get_experience(arg):
    ls_arg = arg.split()
    total_month = 0
    for i in range(len(ls_arg)):
        if ls_arg[i].isdigit() == True:
            if ls_arg[i + 1].count('ле') or ls_arg[i + 1].count('го'):
                total_month += int(ls_arg[i]) *  12
            else:
                total_month += int(ls_arg[i])      
    return total_month
string = 'Опыт работы 3 года 5 месяцев'
print(get_experience(string))
# Out:
# 41
